# %% [markdown]
# <a href="https://colab.research.google.com/github/Manikanta2804/Data_Mining/blob/main/lab-5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
np.random.seed(42)
data=np.random.normal(0,1,100)#Normal distribution
outliers=np.random.uniform(5,10,5)#Artificial distribution

# %%
data_with_outliers=np.concatenate([data,outliers])

# %%
df=pd.DataFrame(data_with_outliers,columns=['value'])
df
# Out:
#         value
# 0    0.496714
# 1   -0.138264
# 2    0.647689
# 3    1.523030
# 4   -0.234153
# ..        ...
# 100  7.087055
# 101  6.110539
# 102  5.599327
# 103  6.688076
# 104  9.714549
#
# [105 rows x 1 columns]

# %%
q1=df['value'].quantile(0.25)
q3=df['value'].quantile(0.75)
ior=q3-q1
lower_bound=q1-1.5*ior
higher_bound=q3+1.5*ior

# %%
print(lower_bound)
print(higher_bound)
# Out:
# -2.3232332563637335
# 2.372622015963629

# %%
outliers_ior=df[(df['value']<lower_bound)|(df['value']>higher_bound)]

# %%
z_scores=stats.zscore(df['value'])
outliers_zscore=df[np.abs(z_scores)>3]

# %%
plt.figure(figsize=(5,6))
plt.boxplot(x=df['value'])
plt.title('box plot of the outliers of distribution')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
